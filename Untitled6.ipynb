# %% [markdown]
# <a href="https://colab.research.google.com/github/hanh211/ha/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !npm install AndroidJS
# Out:
# npm ERR! code E404
# npm ERR! 404 Not Found - GET https://registry.npmjs.org/AndroidJS - Not found
# npm ERR! 404
# npm ERR! 404  'AndroidJS@latest' is not in the npm registry.
# npm ERR! 404 Your package name is not valid, because
# npm ERR! 404  1. name can no longer contain capital letters
# npm ERR! 404
# npm ERR! 404 Note that you can also install from a
# npm ERR! 404 tarball, folder, http url, or git url.
#
# npm ERR! A complete log of this run can be found in:
# npm ERR!     /root/.npm/_logs/2023-10-10T12_57_58_303Z-debug.log

# %%
# !npm i opencv4nodejs
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#                  from ../cc/features2d/detectors/GFTTDetector.h:2,
#                  from ../cc/features2d/detectors/GFTTDetector.cc:5:
# ../cc/core/Vec2.h: In static member function ‘static Nan::NAN_METHOD_RETURN_TYPE Vec2::Sub(Nan::NAN_METHOD_ARGS_TYPE)’:
# ../cc/core/coreUtils.h:47:104: warning: implicitly-declared ‘constexpr cv::Vec<double, 2>& cv::Vec<double, 2>::operator=(const cv::Vec<double, 2>&)’ is deprecated [-Wdeprecated-copy]
#    47 |                 unwrapClassPtrUnchecked(info[0]->ToObject(Nan::GetCurrentContext()).ToLocalChecked())->self,                                                                                                                                                                                            \
#       |                                                                                                        ^~~~
# ...
